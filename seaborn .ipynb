# %%
import pandas as pd
import numpy as np
import matplotlib  as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
iris = sns.load_dataset("iris")
titanic = sns.load_dataset("titanic")
planets = sns.load_dataset("planets")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x = "tip", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x = "tip", y="total_bill", data=tips, hue="day")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x = "tip", y="total_bill", data=tips, hue="day", size="size")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x = "tip", y="total_bill", data=tips, hue="day", size="size", palette="YlGnBu")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# #### hue=determines which column in the data frame should be used for colour encoding

# %%
sns.histplot(tips['tip'],kde=True,bins=15) # Kde= a non-parametric way to estimate the distribution of a variable.#bins=the number of bars
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips['tip'],bins=10)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.distplot(tips['tip'],kde=True, bins=15)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.displot(tips['tip'],kde=True, bins=15)   #we use distplot to represent data in histogram form

# %%
sns.histplot(tips['tip'],kde=True, bins=15)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.barplot(x="sex",y="tip",data=tips, palette="GnBu",ci=True)  #You can remove the confidence interval(ci)by setting the ci parameter
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x="day", y="total_bill", data=tips) #distribution with respect to categories
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day", y="tip", data=tips,hue="sex", palette="YlGnBu")  #represents which column in the data frame, you want to use for color encoding.
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="tip", data=tips, hue="sex", palette="YlGnBu")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x="day", y="tip", data=tips, hue="sex", palette="YlGnBu", dodge=True) # It is basically a scatter plot that differentiates different categories
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x="tip",y="total_bill",data=tips)   #displays a relationship between 2 variables

# %%
sns.jointplot(x="tip",y="total_bill",data=tips , kind="reg")

# %%
sns.jointplot(x="tip",y="total_bill",data=tips , kind="kde")                  #three dim

# %%
sns.jointplot(x="tip",y="total_bill",data=tips , kind="kde", shade=True)

# %%
sns.jointplot(x="tip",y="total_bill",data=tips , kind="kde" , shade=True , cmap="RdBu")

# %%
sns.jointplot(x="tip",y="total_bill",data=tips , kind="hex")

# %%
sns.jointplot(x="tip",y="total_bill",data=tips , kind="hex",cmap ="RdBu")

# %%
sns.jointplot(x="tip",y="total_bill",data=tips , kind="hex",cmap="YlGnBu")

# %%
sns.jointplot(x="tip",y="total_bill",data=tips , kind="hist",cmap="RdBu")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips.select_dtypes(['number']),hue="size")# to plot multiple pairwise bivariate distributions in a dataset

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.pairplot(titanic.select_dtypes(['number']),hue="pclass
# Out:
#   Input In [2]
#     sns.pairplot(titanic.select_dtypes(['number']),hue="pclass
#                                                               ^
# SyntaxError: EOL while scanning string literal

# %%
titanic.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(titanic.corr(), annot=True)  #different shades of same color and annot asigns the values
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(titanic.corr(), annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(titanic.corr(), annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(titanic.corr(), annot=True,cmap="icefire")
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(iris)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 sns.clustermap(iris)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:1406, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
# ...

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.clustermap(iris.drop("species",axis=1))
